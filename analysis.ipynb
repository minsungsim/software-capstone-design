# %%
import pandas as pd
import numpy as np 
import os
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')


pd.set_option('display.max_row', 100)
pd.set_option('display.max_columns', 50)

# %%
df = pd.read_csv('./result_data/merge.csv')
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
t_df = df.copy().iloc[:90000]
t_df['cluster'] = t_df['kmeans_image_label']
t_df['price60'] = (t_df['price'].shift(-60) / t_df['price'] - 1) * 100
t_df.dropna(inplace=True)

grouped = t_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price60'])
result_df = result_df.transpose()

result_df.columns = [1, 2, 3, 4, 5, 6, 7, 8]
result_df = result_df.transpose()
result_df.columns = ['return_rate']

plt.figure(figsize=(20, 6))
result_df.plot(kind='bar', color="black")
plt.title('One-hour Forward Return Rate - Kmeans image version')
plt.xlabel('Cluster')
plt.ylabel('Return (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for idx, value in enumerate(list(result_df.iloc[0])):
    x = value
    if value < 0:
        x = 0

plt.show()

# %%
t_df = df.copy().iloc[:90000]
t_df['cluster'] = t_df['gmm_image_label']
t_df['price60'] = (t_df['price'].shift(-60) / t_df['price'] - 1) * 100
t_df.dropna(inplace=True)

grouped = t_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price60'])
result_df = result_df.transpose()

result_df.columns = [1, 2, 3, 4, 5, 6, 7, 8]
result_df = result_df.transpose()
result_df.columns = ['return_rate']

plt.figure(figsize=(20, 6))
result_df.plot(kind='bar', color="black")
plt.title('One-hour Forward Return Rate - gmm image version')
plt.xlabel('Cluster')
plt.ylabel('Return (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for idx, value in enumerate(list(result_df.iloc[0])):
    x = value
    if value < 0:
        x = 0

plt.show()

# %%
t_df = df.copy().iloc[:90000]
t_df['cluster'] = t_df['kmeans_raw_label']
t_df['price60'] = (t_df['price'].shift(-60) / t_df['price'] - 1) * 100
t_df.dropna(inplace=True)

grouped = t_df.groupby("cluster")
result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price60'])
result_df = result_df.transpose()

result_df.columns = [1, 2, 3, 4, 5, 6, 7, 8]
result_df = result_df.transpose()
result_df.columns = ['return_rate']

plt.figure(figsize=(20, 6))
result_df.plot(kind='bar', color="black")
plt.title('One-hour Forward Return Rate - kmeans raw version')
plt.xlabel('Cluster')
plt.ylabel('Return (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for idx, value in enumerate(list(result_df.iloc[0])):
    x = value
    if value < 0:
        x = 0

plt.show()

# %%
t_df = df.copy().iloc[:90000]
t_df['cluster'] = t_df['gmm_raw_label']
t_df['price60'] = (t_df['price'].shift(-60) / t_df['price'] - 1) * 100
t_df.dropna(inplace=True)

grouped = t_df.groupby("cluster")
result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price60'])
result_df = result_df.transpose()

result_df.columns = [1, 2, 3, 4, 5, 6, 7, 8]
result_df = result_df.transpose()
result_df.columns = ['return_rate']

plt.figure(figsize=(20, 6))
result_df.plot(kind='bar', color="black")
plt.title('One-hour Forward Return Rate - gmm raw version')
plt.xlabel('Cluster')
plt.ylabel('Return (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for idx, value in enumerate(list(result_df.iloc[0])):
    x = value
    if value < 0:
        x = 0

plt.show()

# %%
tt_df = df.copy().iloc[:90000]
tt_df['cluster'] = tt_df['kmeans_raw_label']
tt_df['price60'] = (tt_df['price'].shift(-60) / tt_df['price'] - 1) * 100
tt_df.dropna(inplace=True)

grouped = tt_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price60'])
result_df = result_df.transpose()

df['kmeans_raw_label2'] = 0
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 4, 1, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 2, 7/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 7, 6/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 6, 5/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 5, 4/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 3, 3/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 1, 2/8, df['kmeans_raw_label2'])
df['kmeans_raw_label2'] = np.where(df['kmeans_raw_label'] == 0, 1/8, df['kmeans_raw_label2'])


tt_df = df.copy().iloc[:90000]
tt_df['cluster'] = tt_df['gmm_raw_label']
tt_df['price1'] = (tt_df['price'].shift(-1) / tt_df['price'] - 1) * 100
tt_df['price10'] = (tt_df['price'].shift(-10) / tt_df['price'] - 1) * 100
tt_df['price30'] = (tt_df['price'].shift(-30) / tt_df['price'] - 1) * 100 
tt_df['price60'] = (tt_df['price'].shift(-60) / tt_df['price'] - 1) * 100
tt_df.dropna(inplace=True)

grouped = tt_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price1'])
result_df['price10'] = grouped.mean().sort_values(by='cluster', ascending=True)['price10']
result_df['price30'] = grouped.mean().sort_values(by='cluster', ascending=True)['price30']
result_df['price60'] = grouped.mean().sort_values(by='cluster', ascending=True)['price60']
result_df = result_df.transpose()


df['gmm_raw_label2'] = 0
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 2, 1, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 4, 7/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 6, 6/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 3, 5/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 5, 4/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 7, 3/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 0, 2/8, df['gmm_raw_label2'])
df['gmm_raw_label2'] = np.where(df['gmm_raw_label'] == 1, 1/8, df['gmm_raw_label2'])


tt_df = df.copy().iloc[:90000]
tt_df['cluster'] = tt_df['kmeans_image_label']
tt_df['price1'] = (tt_df['price'].shift(-1) / tt_df['price'] - 1) * 100
tt_df['price10'] = (tt_df['price'].shift(-10) / tt_df['price'] - 1) * 100
tt_df['price30'] = (tt_df['price'].shift(-30) / tt_df['price'] - 1) * 100 
tt_df['price60'] = (tt_df['price'].shift(-60) / tt_df['price'] - 1) * 100
tt_df.dropna(inplace=True)

grouped = tt_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price1'])
result_df['price10'] = grouped.mean().sort_values(by='cluster', ascending=True)['price10']
result_df['price30'] = grouped.mean().sort_values(by='cluster', ascending=True)['price30']
result_df['price60'] = grouped.mean().sort_values(by='cluster', ascending=True)['price60']


result_df = result_df.transpose()
df['kmeans_image_label2'] = 0
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 5, 1, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 6, 7/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 2, 6/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 1, 5/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 0, 4/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 4, 3/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 3, 2/8, df['kmeans_image_label2'])
df['kmeans_image_label2'] = np.where(df['kmeans_image_label'] == 7, 1/8, df['kmeans_image_label2'])


tt_df = df.copy().iloc[:90000]
tt_df['cluster'] = tt_df['kmeans_image_label']
tt_df['price1'] = (tt_df['price'].shift(-1) / tt_df['price'] - 1) * 100
tt_df['price10'] = (tt_df['price'].shift(-10) / tt_df['price'] - 1) * 100
tt_df['price30'] = (tt_df['price'].shift(-30) / tt_df['price'] - 1) * 100 
tt_df['price60'] = (tt_df['price'].shift(-60) / tt_df['price'] - 1) * 100
tt_df.dropna(inplace=True)

grouped = tt_df.groupby("cluster")

result_df = pd.DataFrame(grouped.mean().sort_values(by='cluster', ascending=True)['price1'])
result_df['price10'] = grouped.mean().sort_values(by='cluster', ascending=True)['price10']
result_df['price30'] = grouped.mean().sort_values(by='cluster', ascending=True)['price30']
result_df['price60'] = grouped.mean().sort_values(by='cluster', ascending=True)['price60']


result_df = result_df.transpose()
df['gmm_image_label2'] = 0
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 8, 1, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 8, 7/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 4, 6/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 1, 5/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 2, 4/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 6, 3/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 5, 2/8, df['gmm_image_label2'])
df['gmm_image_label2'] = np.where(df['gmm_image_label'] == 3, 1/8, df['gmm_image_label2'])

# %%
t_df = df.copy().iloc[90000:]
t_df['market_return'] = ((t_df['price'].shift(-1) / t_df['price']).cumprod() - 1) * 100
t_df['kmean_raw_st_return'] = ((1 + (t_df['price'].shift(-1) / t_df['price'] - 1) * (t_df['kmeans_raw_label2'])).cumprod() - 1) * 100
t_df['kmean_image_st_return'] = ((1 + (t_df['price'].shift(-1) / t_df['price'] - 1) * (t_df['kmeans_image_label2'])).cumprod() - 1) * 100
t_df['gmm_raw_st_return'] = ((1 + (t_df['price'].shift(-1) / t_df['price'] - 1) * (t_df['gmm_raw_label2'])).cumprod() - 1) * 100
t_df['gmm_image_st_return'] = ((1 + (t_df['price'].shift(-1) / t_df['price'] - 1) * (t_df['gmm_image_label2'])).cumprod() - 1) * 100


plt.figure(figsize=(20, 8))
plt.title("Return Comparison Over Time")
plt.plot(t_df.datetime, t_df.kmean_raw_st_return, label="kmean_raw")
plt.plot(t_df.datetime, t_df.kmean_image_st_return, label="kmean_image")
plt.plot(t_df.datetime, t_df.gmm_raw_st_return, label="gmm_raw")
plt.plot(t_df.datetime, t_df.market_return, label="market")
plt.plot(t_df.datetime, t_df.gmm_image_st_return, label="gmm_image")

# x축 라벨 및 타이틀 추가
plt.xlabel('Date Time', fontsize=14)
plt.ylabel('Return (%)', fontsize=14)
# x축 날짜 라벨 회전
plt.xticks(rotation=45)
# 그리드 스타일 설정
plt.grid(which='both', linestyle='--', linewidth=0.5)
# 범례 위치 설정
plt.legend(loc='upper left', fontsize=12)
# 배경색 설정
plt.gca().set_facecolor('whitesmoke')
# 그래프 표시
plt.show()
